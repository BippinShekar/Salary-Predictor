# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv('C:/Users/Bippin Shekar/Downloads/student placement data for ML Model/Placement_Data_Full_Class.csv')
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#Converting all string enntries into Digit entries for passing through algorithhms
def find_and_convert(data):
    for i in data:
        x_to_find = data[i].values
        if np.char.isdigit(str(x_to_find[0])) is True:
            continue
        elif np.issubdtype(x_to_find.dtype,np.floating) is True:
            continue
        else:
            to_find_uniques = set(x_to_find)
            dic = {}
            j = 0
            for i in to_find_uniques:
                dic[i] = dic.get(i,0)+j
                j+=1
            for i in range(len(x_to_find)):
                if x_to_find[i] in dic:
                    x_to_find[i] = dic[x_to_find[i]]
    return data
data = find_and_convert(data)
data
# Out:
#      sl_no gender  ssc_p ssc_b  hsc_p hsc_b hsc_s  degree_p degree_t workex  \
# 0        0      1  67.00     0  91.00     0     2     58.00        1      1
# 1        1      1  79.33     1  78.33     0     0     77.48        1      0
# 2        2      1  65.00     1  68.00     1     1     64.00        2      1
# 3        3      1  56.00     1  52.00     1     0     52.00        1      1
# 4        4      1  85.80     1  73.60     1     2     73.30        2      1
# ..     ...    ...    ...   ...    ...   ...   ...       ...      ...    ...
# 210    210      1  80.60     0  82.00     0     2     77.60        2      1
# 211    211      1  58.00     0  60.00     0     0     72.00        1      1
# 212    212      1  67.00     0  67.00     0     2     73.00        2      0
# 213    213      0  74.00     0  66.00     0     2     58.00        2      1
# 214    214      1  62.00     1  58.00     0     0     53.00        2      1
#
#      etest_p specialisation  mba_p status    salary
# ...

# %%
data
# Out:
#      sl_no gender  ssc_p ssc_b  hsc_p hsc_b hsc_s  degree_p degree_t workex  \
# 0        0      1  67.00     0  91.00     0     2     58.00        1      1
# 1        1      1  79.33     1  78.33     0     0     77.48        1      0
# 2        2      1  65.00     1  68.00     1     1     64.00        2      1
# 3        3      1  56.00     1  52.00     1     0     52.00        1      1
# 4        4      1  85.80     1  73.60     1     2     73.30        2      1
# ..     ...    ...    ...   ...    ...   ...   ...       ...      ...    ...
# 210    210      1  80.60     0  82.00     0     2     77.60        2      1
# 211    211      1  58.00     0  60.00     0     0     72.00        1      1
# 212    212      1  67.00     0  67.00     0     2     73.00        2      0
# 213    213      0  74.00     0  66.00     0     2     58.00        2      1
# 214    214      1  62.00     1  58.00     0     0     53.00        2      1
#
#      etest_p specialisation  mba_p status    salary
# ...

# %%
#Removing all NaN values for better and complete functioning data
data = data.fillna(0)

# %%
#Finding the correlation score of all columns with salary
col = 'salary'
correlations = data.corr()[col]
correlations
# Out:
# sl_no             0.002543
# gender            0.143110
# ssc_p             0.538090
# ssc_b            -0.034594
# hsc_p             0.452569
# hsc_b            -0.011544
# hsc_s            -0.005860
# degree_p          0.408371
# degree_t          0.020329
# workex           -0.298285
# etest_p           0.186988
# specialisation   -0.275766
# mba_p             0.139823
# status            0.865774
# salary            1.000000
# Name: salary, dtype: float64

# %%
#Splitting Data into X and Y
X = data.drop('salary',axis=1)
y = data['salary']
Y = pd.DataFrame(y)

# %%
X
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        0       1  67.00      0  91.00      0      2     58.00         1
# 1        1       1  79.33      1  78.33      0      0     77.48         1
# 2        2       1  65.00      1  68.00      1      1     64.00         2
# 3        3       1  56.00      1  52.00      1      0     52.00         1
# 4        4       1  85.80      1  73.60      1      2     73.30         2
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    210       1  80.60      0  82.00      0      2     77.60         2
# 211    211       1  58.00      0  60.00      0      0     72.00         1
# 212    212       1  67.00      0  67.00      0      2     73.00         2
# 213    213       0  74.00      0  66.00      0      2     58.00         2
# 214    214       1  62.00      1  58.00      0      0     53.00         2
#
#      workex  etest_p  specialisation  mba_p  status
# ...

# %%
Y
# Out:
#        salary
# 0    270000.0
# 1    200000.0
# 2    250000.0
# 3         0.0
# 4    425000.0
# ..        ...
# 210  400000.0
# 211  275000.0
# 212  295000.0
# 213  204000.0
# 214       0.0
#
# [215 rows x 1 columns]

# %%
#splitting X's and Y's into train and test sub-datasets after cleaning
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=0) # to make sure we are geting same slpit even when we are checking on different models

# %%
x_train
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 138    138       0  82.00      0  64.00      0      0     73.00         1
# 52      52       0  40.89      0  45.83      0      2     53.00         2
# 66      66       1  83.00      0  74.00      0      0     66.00         2
# 26      26       1  71.00      0  79.00      0      2     66.00         2
# 61      61       1  84.20      1  73.40      1      2     66.89         2
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 67      67       1  80.92      0  78.50      0      2     67.00         2
# 192    192       1  65.20      1  61.40      1      2     64.80         2
# 117    117       1  77.00      0  75.00      0      0     73.00         1
# 47      47       1  63.00      1  60.00      1      2     57.00         2
# 172    172       1  73.00      0  58.00      0      2     56.00         2
#
#      workex  etest_p  specialisation  mba_p  status
# ...

# %%
x_test
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 198    198       0  67.00      1  70.00      1      2     65.00         0
# 37      37       0  79.00      1  76.00      1      0     65.60         1
# 89      89       0  84.00      0  75.00      0      0     69.00         1
# 168    168       0  48.00      1  51.00      1      2     58.00         2
# 171    171       1  80.00      0  80.00      0      2     72.00         2
# 75      75       0  59.00      1  62.00      0      2     77.50         2
# 96      96       0  76.00      1  70.00      1      0     76.00         2
# 137    137       1  67.00      0  63.00      1      2     72.00         2
# 5        5       1  55.00      0  49.80      0      0     67.25         1
# 83      83       1  84.00      0  79.00      0      0     68.00         1
# 55      55       1  60.40      1  66.60      0      0     65.00         2
# 145    145       1  89.40      0  65.66      0      0     71.25         1
# ...

# %%
y_train
# Out:
#        salary
# 138  250000.0
# 52        0.0
# 66   275000.0
# 26   240000.0
# 61   300000.0
# ..        ...
# 67   275000.0
# 192  270000.0
# 117  240000.0
# 47   204000.0
# 172  300000.0
#
# [161 rows x 1 columns]

# %% [markdown]
# ## Testing Before Dropping Columns to see if dropped columns affect Prediction Score

# %%
#Testing Phase - Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.8323477856631928

# %%
y_pred_lr = lr.predict(x_test)
y_pred_lr
# Out:
# array([[ 37837.79418733],
#        [227626.78890486],
#        [264238.2702252 ],
#        [ -4768.20290347],
#        [311964.89915509],
#        [-34059.93093345],
#        [282092.80111162],
#        [270133.8191166 ],
#        [-11241.28017021],
#        [332331.25969859],
#        [246786.74901937],
#        [269729.68514287],
#        [332558.00045691],
#        [262554.30722744],
#        [333262.55498638],
#        [293619.94610314],
#        [308204.48919282],
#        [-29832.56418786],
#        [363339.88708835],
#        [  4650.43687739],
#        [  5993.39432669],
#        [-21198.17549303],
#        [293660.24797326],
#        [-13801.00231048],
#        [   861.36573825],
#        [-32218.46084784],
#        [294421.33123388],
#        [305551.00931987],
#        [288659.24577129],
#        [317403.67693228],
#        [309685.55343591],
#        [-24840.16438155],
#        [293774.88729678],
#        [ 12190.89479456],
#        [  5442.92295717],
# ...

# %%
#Testing Phase - Decisiontreeregressor
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr.score(x_test,y_test)
# Out:
# 0.3020575640725196

# %%
y_pred_dtr = dtr.predict(x_test)
y_pred_dtr
# Out:
# array([     0., 240000., 300000.,      0., 295000.,      0., 240000.,
#        240000.,      0., 240000., 265000., 350000., 500000., 240000.,
#        940000., 240000., 275000.,      0., 236000.,      0.,      0.,
#             0., 250000.,      0.,      0.,      0., 240000., 350000.,
#        275000., 240000., 300000.,      0., 265000.,      0.,      0.,
#        350000., 393000., 233000., 240000., 233000.,      0.,      0.,
#        265000., 278000., 295000., 360000., 275000., 300000.,      0.,
#        250000., 231000., 218000., 500000., 350000.])

# %%
#Testing Phase - RandomForestregressor
y_trainrav = y_train.values
y_trainrav = y_trainrav.ravel()
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(x_train,y_trainrav)
rfr.score(x_test,y_test)
# Out:
# 0.7399290931363529

# %%
y_pred_rfr = rfr.predict(x_test)
y_pred_rfr
# Out:
# array([     0., 277100., 274460.,      0., 295220.,      0., 244060.,
#        270810.,      0., 295850., 345490., 291570., 340390., 283320.,
#        497530., 273790., 254640.,      0., 518200.,      0.,      0.,
#             0., 273290.,      0.,      0.,      0., 320990., 290740.,
#        265990., 287490., 274810.,      0., 262110.,      0.,      0.,
#        290030., 337720., 309680., 278930., 335830.,      0.,      0.,
#        265220., 270740., 338520., 273930., 262300., 250230.,      0.,
#        242690., 272340., 427270., 413210., 320160.])

# %%
#Testing Phase - Support Vector regression
y_trainsvrav = y_train.values
y_trainsvrav = y_trainsvrav.ravel()
from sklearn.svm import SVR
svm = SVR()
svm.fit(x_train,y_trainsvrav)
svm.score(x_test,y_test)
# Out:
# -0.23967219802628148

# %%
#Testing Phase - Graident Boosting Regression
y_traingbrav = y_train.values
y_traingbrav = y_traingbrav.ravel()
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_traingbrav)
gbr.score(x_test,y_test)
# Out:
# 0.7740118436734559

# %%
y_pred_gbr = gbr.predict(x_test)
y_pred_gbr
# Out:
# array([ 35879.1702215 , 243235.64603311, 273844.74448185,   2211.45600822,
#        322885.5169263 ,  -3465.42609571, 287286.46644887, 254584.06707642,
#         20424.52089254, 318696.89971126, 300041.96594686, 296387.37856718,
#        359613.98653017, 266304.85358035, 399547.15061525, 256609.37031139,
#        273572.23746373, -12670.18884943, 467424.35983903,  27601.16270009,
#         37146.59167066,  12825.7101907 , 273045.75234086, -20887.88607159,
#          2925.78067869,   2997.28306881, 313155.10702505, 252790.74347853,
#        284981.16457881, 321412.17706821, 259731.4550972 ,  12953.69486936,
#        254612.31117205,    885.90002013,  17955.70575777, 291251.806538  ,
#        305792.38565142, 287813.79679711, 230863.76261987, 265940.85384401,
#         14568.48975251,  20881.22773426, 250175.83631461, 267266.47303005,
#        378157.11186952, 284144.4211676 , 285761.44616143, 255687.66583799,
# ...

# %% [markdown]
# ## Dropping Columns based of correlation with target

# %%
correlationmat = data.corr()
correlationmat
# Out:
#                    sl_no    gender     ssc_p     ssc_b     hsc_p     hsc_b  \
# sl_no           1.000000  0.074306 -0.078155 -0.027214 -0.085711 -0.116887
# gender          0.074306  1.000000 -0.068969 -0.019429 -0.021334 -0.065945
# ssc_p          -0.078155 -0.068969  1.000000 -0.116194  0.511472 -0.066996
# ssc_b          -0.027214 -0.019429 -0.116194  1.000000  0.137013  0.605883
# hsc_p          -0.085711 -0.021334  0.511472  0.137013  1.000000  0.019548
# hsc_b          -0.116887 -0.065945 -0.066996  0.605883  0.019548  1.000000
# hsc_s          -0.021894 -0.022330 -0.149061  0.059053  0.248657  0.102392
# degree_p       -0.088281 -0.173217  0.538404 -0.038070  0.434206 -0.067229
# degree_t       -0.057564  0.006157 -0.119835  0.075573  0.140902 -0.022222
# workex         -0.059151 -0.085153 -0.175675 -0.040744 -0.141025  0.038357
# etest_p         0.063636  0.084294  0.261993  0.018991  0.245113 -0.039108
# ...

# %%
#PLotting the corelation matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Plot the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlationmat, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation')
plt.show()

# %%
#lets drop gender as it has -ve correlation
x_train_pgd = x_train.drop('gender',axis=1)
x_test_pgd = x_test.drop('gender',axis=1)

# %%
#Post gender drop test phase - Linearregression
lrpg = LinearRegression() 
lrpg.fit(x_train_pgd,y_train)
lrpg.score(x_test_pgd,y_test)
# Out:
# 0.819549310122033

# %%
#remarks - Post gnder drop ressulted in further drop in accuracy. Verdict - Keep Gender in dataframe

# %%
#Lets drop ssc_b as correlation is very very minute
x_train_pssc = x_train.drop('ssc_b',axis=1)
x_test_pssc = x_test.drop('ssc_b',axis=1)

# %%
#Post ssc_b drop test phase - LinearRegression
lrpssc = LinearRegression()
lrpssc.fit(x_train_pssc,y_train)
lrpssc.score(x_test_pssc,y_test)
# Out:
# 0.8337511603304503

# %%
#remarks as dropping ssc_b increase accuracy. Verdict - Drop ssc_b from dataframe
x_train = x_train.drop('ssc_b',axis=1)
x_test = x_test.drop('ssc_b',axis=1)

# %%
#Lets drop hsc_b as it has very minute correlation with target.
x_train_phsc = x_train.drop('hsc_b',axis=1)
x_test_phsc = x_test.drop('hsc_b',axis=1)

# %%
#Post hsc_b drop Testing Phase - Linear Regression
lrphsc = LinearRegression()
lrphsc.fit(x_train_phsc,y_train)
lrphsc.score(x_test_phsc,y_test)
# Out:
# 0.8334851876881053

# %%
#remarks - dropping hsc_b also dropped accuraccy. Verdict - lets hsc_b stay.

# %%
#Lets drop hsc_s as correlation is less.
x_trainphsc_s = x_train.drop('hsc_s',axis=1)
x_testphsc_S = x_test.drop('hsc_s',axis=1)

# %%
# post hsc_s drop tesst phase _ LR
lrphsc_s = LinearRegression()
lrphsc_s.fit(x_trainphsc_s,y_train)
lrphsc_s.score(x_testphsc_S,y_test)
# Out:
# 0.8332974745083928

# %%
#remarks - dropping hcs_s decreased accuracy. Verdict - Let hsc_s stay.

# %%
#lets drop degree_t.
x_trainpdt = x_train.drop('degree_t',axis=1)
x_testpdt = x_test.drop('degree_t',axis=1)

# %%
#post degree_t drop test phase - LR
lrpdt = LinearRegression()
lrpdt.fit(x_trainpdt,y_train)
lrpdt.score(x_testpdt,y_test)
# Out:
# 0.8285185419038514

# %%
#remarks - dropping degree_t decreases accuraccy. Verdict - keep degree_t

# %%
#Lets see if using PCA increases accuraccy

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 13)
x_train_pca = pca.fit_transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
#test phase post PCA
lr_pca = LinearRegression()
lr_pca.fit(x_train_pca,y_train)
lr_pca.score(x_test_pca,y_test)
# Out:
# 0.8337511603304502

# %%
#test phase - RFC
y_train_ravpca = y_train.values
y_train_ravpca = y_train_ravpca.ravel()
rfr_pca = RandomForestRegressor()
rfr_pca.fit(x_train_pca,y_train_ravpca)
rfr_pca.score(x_test_pca,y_test)
# Out:
# 0.5115942268902192

# %%
# test phase - gbr
y_train_ravpcagbr = y_train.values
y_train_ravpcagbr = y_train_ravpcagbr.ravel()
gbr_pca = GradientBoostingRegressor()
gbr_pca.fit(x_train_pca,y_train_ravpcagbr)
gbr_pca.score(x_test_pca,y_test)
# Out:
# 0.7056575942053995

# %%
#dropping features contributing in PCA to 13 
Pca = PCA(n_components=12)
x_train_Pca = Pca.fit_transform(x_train)
x_test_Pca = Pca.transform(x_test)

# %%
#testing phase pca12 - lr
lr_pca12 = LinearRegression()
lr_pca12.fit(x_train_Pca,y_train)
lr_pca12.score(x_test_Pca,y_test)
# Out:
# 0.4040508252137548

# %%
#testing phase pca12 - gbr
y_train = y_train.values
y_train_pca12rav = y_train.ravel()
gbr_pca12 = GradientBoostingRegressor()
gbr_pca12.fit(x_train_Pca,y_train_pca12rav)
gbr_pca12.score(x_test_Pca,y_test)
# Out:
# 0.1194044016179987

# %%
#testing phase pca12 - rfr
y_train_pca12ravrfr = y_train.ravel()
rfr_pca12 = RandomForestRegressor()
rfr_pca12.fit(x_train_Pca,y_train_pca12ravrfr)
rfr_pca12.score(x_test_Pca,y_test)
# Out:
# 0.3304658932424869

# %% [markdown]
# ## Try to convert all data points in X to single digits to see if it makes any progress in accuraccy of the model

# %%
def convert_all(data):
    for i in data:
        x_to_convert = data[i].values
        if x_to_convert[0]/10>1:
            for i in range(len(x_to_convert)):
                x_to_convert[i] = x_to_convert[i]/10
    return data
X = convert_all(X)

# %%
X
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        0       1  6.700      0  9.100      0      2     5.800         1
# 1        1       1  7.933      1  7.833      0      0     7.748         1
# 2        2       1  6.500      1  6.800      1      1     6.400         2
# 3        3       1  5.600      1  5.200      1      0     5.200         1
# 4        4       1  8.580      1  7.360      1      2     7.330         2
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    210       1  8.060      0  8.200      0      2     7.760         2
# 211    211       1  5.800      0  6.000      0      0     7.200         1
# 212    212       1  6.700      0  6.700      0      2     7.300         2
# 213    213       0  7.400      0  6.600      0      2     5.800         2
# 214    214       1  6.200      1  5.800      0      0     5.300         2
#
#      workex  etest_p  specialisation  mba_p  status
# ...

# %%
#splitting transformed X data
x_trans_train,x_trans_test,y_train,y_test = train_test_split(X,Y,random_state=0)

# %%
#test phase - using transformed X data
lr_trans = LinearRegression()
lr_trans.fit(x_trans_train,y_train)
lr_trans.score(x_trans_test,y_test)
# Out:
# 0.8323477856631927

# %% [markdown]
# ## As the dataset is not expansive enough, the accuraccy of the predictions have maxed out at 83.1%.
# ## I have tried to reduce the features, however it also reduced the accuraccy in most cases.
# ## Even in PCA, decreasing features by even 1 is causing a drastic drop in the accuraccy.
# ## Thus, I have concluded that it is safe to assume that 83.3% is highest accuracy of the model - Salary Prediction of Placed Students.

# %% [markdown]
# # As the max accuraccy score till now is 83.37511. It is outputed by both lr_pca and lr_pssc
# ## lets look at their preicted values

# %%
y_pred_lr_pca = lr_pca.predict(x_test_pca)
y_pred_lr_pca
# Out:
# array([[ 39432.75744713],
#        [227674.44380727],
#        [262057.38689317],
#        [ -5136.0238505 ],
#        [309478.31929675],
#        [-30063.21297675],
#        [281490.79893381],
#        [265179.9565961 ],
#        [-13266.16908642],
#        [330404.55474386],
#        [249559.30062401],
#        [269014.01591937],
#        [333048.31067311],
#        [260907.86064699],
#        [334374.41606039],
#        [291869.27958718],
#        [307309.51769724],
#        [-26338.8683946 ],
#        [361215.67122171],
#        [  2786.12515191],
#        [  5596.82537785],
#        [-21942.55175693],
#        [293197.04501928],
#        [-19811.60115909],
#        [  -865.27715581],
#        [-31711.7098167 ],
#        [296136.20461863],
#        [305540.58132061],
#        [287476.24964756],
#        [316779.0794861 ],
#        [310930.7947405 ],
#        [-27232.31543721],
#        [292976.02851269],
#        [ 17203.25371869],
#        [  5029.80091882],
# ...

# %%
y_pred_lrpssc = lrpssc.predict(x_test)
y_pred_lrpssc
# Out:
# array([[ 39432.75744713],
#        [227674.44380727],
#        [262057.38689317],
#        [ -5136.0238505 ],
#        [309478.31929675],
#        [-30063.21297675],
#        [281490.79893381],
#        [265179.9565961 ],
#        [-13266.16908642],
#        [330404.55474386],
#        [249559.30062401],
#        [269014.01591937],
#        [333048.31067311],
#        [260907.86064699],
#        [334374.41606038],
#        [291869.27958718],
#        [307309.51769724],
#        [-26338.8683946 ],
#        [361215.67122171],
#        [  2786.12515191],
#        [  5596.82537785],
#        [-21942.55175693],
#        [293197.04501928],
#        [-19811.60115908],
#        [  -865.27715581],
#        [-31711.7098167 ],
#        [296136.20461863],
#        [305540.58132061],
#        [287476.24964756],
#        [316779.0794861 ],
#        [310930.7947405 ],
#        [-27232.31543721],
#        [292976.02851269],
#        [ 17203.25371869],
#        [  5029.80091882],
# ...

# %%
As both lr_pca and lrpssc predict the same values. Let's save one of these as the final predictions.
Y_pred = pd.DataFrame(y_pred_lr_pca)
Y_pred_finals = Y_pred.to_csv('C:/Users/Bippin Shekar/Downloads/student placement data for ML Model/Y_salary_prediction_finals.csv')

# %% [markdown]
# ## Note the acurracy percentages might change in ever re-run, however, the conclusion holds strong for almost every case.
